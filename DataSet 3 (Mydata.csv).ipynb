# %%
import pandas as pd
from scipy import stats
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as sk
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('MyData.csv')

# %%
df_tr = df

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df["school"] = df["school"].astype('category')

# %%
df["school"] = df["school"].cat.codes

# %%
df["sex"] = df["sex"].astype('category')
df["address"] = df["address"].astype('category')
df["famsize"] = df["famsize"].astype('category')
df["Pstatus"] = df["Pstatus"].astype('category')
df["Mjob"] = df["Mjob"].astype('category')
df["Fjob"] = df["Fjob"].astype('category')
df["reason"] = df["reason"].astype('category')
df["guardian"] = df["guardian"].astype('category')
df["schoolsup"] = df["schoolsup"].astype('category')
df["famsup"] = df["famsup"].astype('category')
df["paid"] = df["paid"].astype('category')
df["activities"] = df["activities"].astype('category')
df["nursery"] = df["nursery"].astype('category')
df["higher"] = df["higher"].astype('category')
df["internet"] = df["internet"].astype('category')
df["romantic"] = df["romantic"].astype('category')

# %%
df["sex"] = df["sex"].cat.codes
df["address"] = df["address"].cat.codes
df["famsize"] = df["famsize"].cat.codes
df["Pstatus"] = df["Pstatus"].cat.codes
df["Mjob"] = df["Mjob"].cat.codes
df["Fjob"] = df["Fjob"].cat.codes
df["reason"] = df["reason"].cat.codes
df["guardian"] = df["guardian"].cat.codes
df["schoolsup"] = df["schoolsup"].cat.codes
df["famsup"] = df["famsup"].cat.codes
df["paid"] = df["paid"].cat.codes
df["activities"] = df["activities"].cat.codes
df["nursery"] = df["nursery"].cat.codes
df["higher"] = df["higher"].cat.codes
df["internet"] = df["internet"].cat.codes
df["romantic"] = df["romantic"].cat.codes

# %%
df.head()
df_tr = df

# %%
import matplotlib.pyplot as plt
get_ipython().magic('matplotlib inline')

# %%
df.plot.scatter(x='age', y='studytime', c='G3')
plt.show()

# %%
df.plot.scatter(x='traveltime', y='studytime', c='G3')
plt.show()

# %%
df.plot.scatter(x='absences', y='studytime', c='G3')
plt.show()

# %%
import matplotlib.pyplot as plt
get_ipython().magic('matplotlib inline')

# %%
import matplotlib.pyplot as plt1
# %matplotlib inline

# %%
sns.barplot(df['age'],df['G3'], alpha=0.9)

# %%
plt.plot(df['traveltime'],df['absences'])

# %%
sns.barplot(df['traveltime'],df['absences'], alpha=0.9)

# %%
df.plot.scatter(x='G1', y='G2', c='G3')
plt.show()

# %%
plt.plot(df['G1'],df['G2'],df['G3'])

# %%
df.plot.box()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
plt.show()

# %%
sns.barplot(df['age'],df['G3'], alpha=0.9)

# %%
sns.barplot(df['freetime'],df['absences'], alpha=0.9)

# %%
sns.barplot(df['failures'],df['G3'], alpha=0.9)

# %%
sns.barplot(df['failures'],df['absences'], alpha=0.9)

# %%
Y = df_tr['G3']

# %%
X = df_tr.drop('G3',1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
regressor.score(X_test, y_test)
# Out:
# 0.8268900409685993

# %%
df_tr.shape
# Out:
# (1044, 33)

# %%
df_tr.describe()
# Out:
#             school          sex          age      address      famsize  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.260536     0.433908    16.726054     0.727011     0.293103
# std       0.439138     0.495850     1.239975     0.445708     0.455404
# min       0.000000     0.000000    15.000000     0.000000     0.000000
# 25%       0.000000     0.000000    16.000000     0.000000     0.000000
# 50%       0.000000     0.000000    17.000000     1.000000     0.000000
# 75%       1.000000     1.000000    18.000000     1.000000     1.000000
# max       1.000000     1.000000    22.000000     1.000000     1.000000
#
#            Pstatus         Medu         Fedu         Mjob         Fjob  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.884100     2.603448     2.387931     2.027778     2.246169
# std       0.320259     1.124907     1.099938     1.244815     0.863522
# ...

# %%
df_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 33 columns):
# school        1044 non-null int8
# sex           1044 non-null int8
# age           1044 non-null int64
# address       1044 non-null int8
# famsize       1044 non-null int8
# Pstatus       1044 non-null int8
# Medu          1044 non-null int64
# Fedu          1044 non-null int64
# Mjob          1044 non-null int8
# Fjob          1044 non-null int8
# reason        1044 non-null int8
# guardian      1044 non-null int8
# traveltime    1044 non-null int64
# studytime     1044 non-null int64
# failures      1044 non-null int64
# schoolsup     1044 non-null int8
# famsup        1044 non-null int8
# paid          1044 non-null int8
# activities    1044 non-null int8
# nursery       1044 non-null int8
# higher        1044 non-null int8
# internet      1044 non-null int8
# romantic      1044 non-null int8
# famrel        1044 non-null int64
# freetime      1044 non-null int64
# ...

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.8553283206253884

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1.6252069114531977

# %%
from sklearn.neighbors import KNeighborsClassifier  
classifier = KNeighborsClassifier(n_neighbors=7)  
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=7, p=2,
#            weights='uniform')

# %%
y_pred = classifier.predict(X_test)

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 29.1866028708134
